# %% [markdown]
# # Cancer Classification

# %%
import numpy as np
import torch 
from torch import nn
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv("Cancer_Data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0    842302         M        17.99         10.38          122.80     1001.0  \
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.dropna(axis='columns')
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0      842302         M        17.99         10.38          122.80     1001.0  \
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["diagnosis"] = le.fit_transform(df["diagnosis"])

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0    842302          1        17.99         10.38          122.80     1001.0  \
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
col_x = ["radius_mean",'texture_mean','smoothness_mean','concavity_mean','symmetry_mean','fractal_dimension_mean']
col_y = ['diagnosis']
X = df[col_x]
y = df[col_y]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state=5)

# %%
X_train
# Out:
#      radius_mean  texture_mean  smoothness_mean  concavity_mean
# 47        13.170         18.66          0.11580         0.12260  \
# 527       12.340         12.27          0.09003         0.02958
# 435       13.980         19.62          0.10600         0.11260
# 21         9.504         12.44          0.10240         0.02956
# 554       12.880         28.92          0.08123         0.06195
# ..           ...           ...              ...             ...
# 8         13.000         21.82          0.12730         0.18590
# 73        13.800         15.79          0.10070         0.07789
# 400       17.910         21.02          0.12300         0.31890
# 118       15.780         22.91          0.11550         0.21330
# 206        9.876         17.27          0.10890         0.01756
#
#      symmetry_mean  fractal_dimension_mean
# 47          0.2128                 0.06777
# 527         0.1689                 0.05808
# 435         0.1669                 0.06544
# ...

# %%
from sklearn.preprocessing import StandardScaler
se = StandardScaler()
X_train = se.fit_transform(X_train)
X_test = se.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.34532146,  1.46339394,  0.83364481,  1.05645178,  0.44098437,
#          0.45705793],
#        [-0.52464298,  0.7387143 ,  0.33365246, -0.41620579, -0.91816737,
#          0.79364578],
#        [ 0.11019589, -1.95329111,  0.96935721,  0.02996066,  0.18727603,
#          0.24688202],
#        ...,
#        [ 0.11901301,  0.05442709, -0.90347159,  0.026748  , -1.2008709 ,
#         -0.75221782],
#        [-0.90672201, -0.99338796, -1.18989577, -0.65059737,  0.72006343,
#          0.00929143],
#        [-1.3099622 , -0.24019659, -0.95847094, -0.91621542, -0.45061928,
#          0.26211245]])

# %%
class LogisticRegression(nn.Module):
    def __init__(self,n_in):
        super().__init__()
        self.in_layer = nn.Linear(in_features=n_in,out_features=1)
        
    def forward(self,x: torch.Tensor) -> torch.Tensor:
        return self.in_layer(x)

# %%
model = LogisticRegression(6)
loss_func = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(params=model.parameters(),lr=0.1)

# %%
X_train = torch.from_numpy(X_train).type(torch.float)
y_train = torch.from_numpy(y_train.values).type(torch.float)
X_test = torch.from_numpy(X_test).type(torch.float)
y_test = torch.from_numpy(y_test.values).type(torch.float)

# %%
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item() # torch.eq() calculates where two tensors are equal
    acc = (correct / len(y_pred)) * 100 
    return acc

# %%
ep = 500

for i in range(ep):
    model.train()
    yloss = torch.sigmoid(model(X_train).squeeze())
    y_pred = torch.round(yloss)
    loss = loss_func(yloss,y_train.squeeze())
    acc = accuracy_fn(y_train.squeeze(),y_pred)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    model.eval()
    with torch.inference_mode():
        yloss = torch.sigmoid(model(X_test).squeeze())
        yp = torch.round(torch.sigmoid(model(X_test).squeeze()))
        loss_test = loss_func(yloss,y_test.squeeze())
        acc_test = accuracy_fn(y_test.squeeze(),yp)
        
    if i%10 == 0:
        print(f"Epoch: {i} | Train Loss: {loss} | Train Accuracy: {acc} | Test Loss: {loss_test} | Test Accuracy: {acc_test}")
# Out:
# Epoch: 0 | Train Loss: 0.8392530083656311 | Train Accuracy: 20.100502512562816 | Test Loss: 0.8161723613739014 | Test Accuracy: 37.42690058479532
# Epoch: 10 | Train Loss: 0.6327764391899109 | Train Accuracy: 89.19597989949749 | Test Loss: 0.6314692497253418 | Test Accuracy: 91.81286549707602
# Epoch: 20 | Train Loss: 0.6014034748077393 | Train Accuracy: 91.70854271356784 | Test Loss: 0.5999458432197571 | Test Accuracy: 93.56725146198829
# Epoch: 30 | Train Loss: 0.5929375886917114 | Train Accuracy: 91.4572864321608 | Test Loss: 0.5903759002685547 | Test Accuracy: 93.56725146198829
# Epoch: 40 | Train Loss: 0.5895049571990967 | Train Accuracy: 92.21105527638191 | Test Loss: 0.5863744616508484 | Test Accuracy: 94.15204678362574
# Epoch: 50 | Train Loss: 0.5876244902610779 | Train Accuracy: 92.21105527638191 | Test Loss: 0.5842594504356384 | Test Accuracy: 95.90643274853801
# ...

# %%
y_pred.shape
# Out:
# torch.Size([398])

# %%
y_train.shape
# Out:
# torch.Size([398, 1])
